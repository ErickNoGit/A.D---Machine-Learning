# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickNoGit/Machine-Learning/blob/main/filtroAno2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Apresentação de Dados de 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
dataFrame = pd.read_csv('/content/ANO2022FILTRO.csv')
dataFrame.columns.to_list()
dataFrame = pd.DataFrame(dataFrame)
contagem = dataFrame.SETOR
display(dataFrame.columns)
# Out:
# Index(['ASSUNTO', 'SETOR', 'ABERTOS NO PORTAL', 'ABERTOS INTERNAMENTE',
#        'TOTAL'],
#       dtype='object')

# %%
# Agrupando os dados por setor e somando as quantidades totais
dataFrameAgrupado = dataFrame.groupby('SETOR')['TOTAL'].sum().reset_index()

# Criando um gráfico de barras com o pacote Seaborn
sns.set_style('whitegrid')
sns.set_palette('Set2')
plt.figure(figsize=(10,6))
ax = sns.barplot(x='SETOR', y='TOTAL', data=dataFrameAgrupado)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Adicionando títulos ao gráfico
plt.title('Quantidade Total por Setor')
plt.xlabel('Setor')
plt.ylabel('TOTAL')

# Mostrando o gráfico
plt.show()
